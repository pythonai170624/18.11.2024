# %%
import pandas as pd
import numpy as np
tips = pd.read_csv(r"tips.csv")

def last_four(num):
    return str(num)[-4:]

print(last_four(1827361))
#tips['last_four'] = tips['CC Number'].apply(last_four)

tips['last_four'] = tips['CC Number'].apply(lambda value: str(value)[-4:])

# write apply -- 'shotrtg' : sex="Male" -- M "Female" -- F
#tips['shortg'] = tips['sex'].apply(lambda g: "M" if g == "Male" else "F")

#tips['shortg_m'] = tips['sex'].map(lambda g: "M" if g == "Male" else "F")

tips['shortg'] = tips['sex'].map({"Male" : 0, "Female": 1})  # can also use dict

tips['gender'] = tips['sex'].replace(['Female', 'Male'],['F', 'M'])

df = pd.DataFrame({
    'First Name': ['John', 'Jane', 'Alice'],
    'Last Name': ['Doe', 'Smith', 'Johnson']
})
print(df)
df['Full name'] = df.apply(lambda row: f"{row['First Name']} {row['Last Name']}", axis=1)
df

# def sum_x(y, b):
#     return a + b
# lambda a, b: a + b

# combinig 2 serties into df
# s1 = pd.Series([10, 20, 30, 40],name="Numbers")
# pd1 = s1.to_frame()
# print(pd1)
# s2 = pd.Series([10, 20, 30, 40],name="Numbers2")
# pd2 = pd.DataFrame({'A': s1, 'B': s2})
# print(pd2)

# 'generous': tips -- tip / total_bill > 0.2 --> generous , not generous
tips['generous'] = tips.apply(lambda row: 'Generous' if row['tip'] / row['total_bill'] > 0.2 else "Not Generous", axis=1)
tips

def is_gen(total_bill, tip):
    return "Generous" if tip / total_bill > 0.2 else "Not Generous"
    
tips['generous_v'] = np.vectorize(is_gen)(tips['total_bill'], tips['tip'])
tips['generous_v'] = tips.apply(lambda row: 'Generous' if row['tip'] / row['total_bill'] > 0.2 else "Not Generous", axis=1)
tips['generous_v'] = np.vectorize(lambda total_bill, tip:"Generous" if tip / total_bill > 0.2 else "Not Generous")(tips['total_bill'], tips['tip'])
tips
# Out:
# 7361
#   First Name Last Name
# 0       John       Doe
# 1       Jane     Smith
# 2      Alice   Johnson
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# ...

# %%
tips = pd.read_csv(r"tips.csv")
sort_by_tips = tips.sort_values(['tip'], ascending=True)  # default
sort_by_tips_desc = tips.sort_values(['tip'], ascending=False)
sort_by_payername = tips.sort_values(['Payer Name'])
sort_by_size = tips.sort_values(['size', 'price_per_person'], ascending=[True, False])
sort_by_size

tips.sort_values(by='Payer Name', key=lambda col_payer_name: col_payer_name.apply(lambda payer_name: len(payer_name)))
# 91 88 1007
#  1  8    7
#  1  7   8
# 91  1007 88
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2              5.80
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2              5.32
# 70        12.02  1.97    Male     No   Sat  Dinner     2              6.01
# 91        22.49  3.50    Male     No   Fri  Dinner     2             11.24
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 147       11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 118       12.43  1.80  Female     No  Thur   Lunch     2              6.22
# 104       20.92  4.08  Female     No   Sat  Dinner     2             10.46
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
# 68        20.23  2.01    Male     No   Sat  Dinner     2             10.12
#
#                 Payer Name         CC Number Payment ID
# ...

# %%
tips = pd.read_csv(r"tips.csv")
print(tips['sex'].value_counts())
print(tips['sex'].value_counts(normalize=True) * 100)
tips['generous_v'] = tips.apply(lambda row: 'Generous' if row['tip'] / row['total_bill'] > 0.2 else "Not Generous", axis=1)
print(tips[['generous_v', 'sex']].value_counts(ascending=True))
print(tips['time'].value_counts())  # Series
print(list(tips['time'].unique()))
print(tips['time'].nunique())
print(tips['tip'].nunique())
print(tips['Payment ID'].nunique())
print(tips.shape)
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# sex
# Male      64.344262
# Female    35.655738
# Name: proportion, dtype: float64
# generous_v    sex
# Generous      Female     15
#               Male       24
# Not Generous  Female     72
#               Male      133
# Name: count, dtype: int64
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64
# ['Dinner', 'Lunch']
# 2
# 123
# 243
# (244, 12)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob', 'David'],
    'Age': [25, 30, 25, 35, 30, 40]
}
df = pd.DataFrame(data)
print(df)
print()

duplicates = df.duplicated()
print(duplicates)

print()
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)

print()
# show only duplicates
all_duplicates = df[df.duplicated(keep=False)]
print(all_duplicates)

print()
print(df.drop_duplicates())
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2    Alice   25
# 3  Charlie   35
# 4      Bob   30
# 5    David   40
#
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool
#
#     Name  Age
# 2  Alice   25
# 4    Bob   30
#
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  Alice   25
# 4    Bob   30
#
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35
# 5    David   40

# %%
tips = pd.read_csv(r"tips.csv")
tips.nlargest(10, 'tip')
tips.nsmallest(10, 'tip')
tips.sample(5)
tips.sample(frac = 0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 40        16.04  2.24    Male     No   Sat  Dinner     3              5.35
# 64        17.59  2.64    Male     No   Sat  Dinner     3              5.86
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2              6.64
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# 17        16.29  3.71    Male     No   Sun  Dinner     3              5.43
# 44        30.40  5.60    Male     No   Sun  Dinner     4              7.60
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2             14.22
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1              8.58
# ...

# %%
print(np.NaN is None)
# Out:
# False
